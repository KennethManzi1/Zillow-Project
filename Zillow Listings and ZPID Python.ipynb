# %%
import pandas as pd
import numpy as np
import plotly.express as px
import requests
import warnings

# %% [markdown]
# ### Listings in Minneapolis(Multifamily)

# %%
url = "https://app.scrapeak.com/v1/scrapers/zillow/listing"
api_key = 'fe4ba972-163e-4dec-8a39-fd9e4e82d6dc'
listing_url = 'https://www.zillow.com/minneapolis-mn/?searchQueryState=%7B%22pagination%22%3A%7B%7D%2C%22isMapVisible%22%3Atrue%2C%22mapBounds%22%3A%7B%22west%22%3A-93.36034635009766%2C%22east%22%3A-93.12345364990234%2C%22south%22%3A44.92864696015096%2C%22north%22%3A45.06824100973466%7D%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A5983%2C%22regionType%22%3A6%7D%5D%2C%22filterState%22%3A%7B%22land%22%3A%7B%22value%22%3Afalse%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22apa%22%3A%7B%22value%22%3Afalse%7D%2C%22manu%22%3A%7B%22value%22%3Afalse%7D%2C%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22con%22%3A%7B%22value%22%3Afalse%7D%2C%22apco%22%3A%7B%22value%22%3Afalse%7D%2C%22tow%22%3A%7B%22value%22%3Afalse%7D%7D%2C%22isEntirePlaceForRent%22%3Atrue%2C%22isRoomForRent%22%3Afalse%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A12%7D'
querystring = {
        "api_key": api_key,
        "url":listing_url
    }
#transform to json
z = requests.request("GET", url, params=querystring)
z_for = z.json()
z_for
# Out:
# {'is_success': True,
#  'data': {'user': {'isLoggedIn': False,
#    'hasHousingConnectorPermission': False,
#    'savedHomesCount': 0,
#    'personalizedSearchTraceID': '04d5b8ee5afcf75dcfd461f26bc01ffa',
#    'guid': '82ea9884-7492-4aba-ad65-557afd1b4b67',
#    'zuid': '',
#    'isBot': False,
#    'email': '',
#    'displayName': ''},
#   'mapState': {'customRegionPolygonWkt': None,
#    'schoolPolygonWkt': None,
#    'isCurrentLocationSearch': False,
#    'userPosition': {'lat': None, 'lon': None}},
#   'regionState': {'regionInfo': [{'regionId': 5983,
#      'regionType': 6,
#      'regionName': 'Minneapolis',
#      'displayName': 'Minneapolis MN',
#      'isPointRegion': False}],
#    'regionBounds': {'north': 45.05125,
#     'south': 44.890144,
#     'east': -93.193794,
#     'west': -93.329163}},
#   'searchPageSeoObject': {'baseUrl': '/minneapolis-mn/',
#    'windowTitle': 'Minneapolis MN Real Estate - Minneapolis MN Homes For Sale | Zillow',
# ...

# %%
# view data
property_data = z_for["data"]["cat1"]["searchResults"]["mapResults"]
property_data
# Out:
# [{'zpid': '1712509',
#   'rawHomeStatusCd': 'ForSale',
#   'marketingStatusSimplifiedCd': 'Non Owner Occupied',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/cce62f3c4e92cd890925d69848aaa281-p_e.jpg',
#   'hasImage': True,
#   'detailUrl': '/homedetails/3536-1st-Ave-S-Minneapolis-MN-55408/1712509_zpid/',
#   'statusType': 'FOR_SALE',
#   'statusText': 'Foreclosure',
#   'price': '$385,000',
#   'priceLabel': '$385K',
#   'address': '3536 1st Ave S, Minneapolis, MN 55408',
#   'beds': 3,
#   'baths': 2.0,
#   'area': 1861,
#   'latLong': {'latitude': 44.93835, 'longitude': -93.276985},
#   'hdpData': {'homeInfo': {'zpid': 1712509,
#     'streetAddress': '3536 1st Ave S',
#     'zipcode': '55408',
#     'city': 'Minneapolis',
#     'state': 'MN',
#     'latitude': 44.93835,
#     'longitude': -93.276985,
#     'price': 385000.0,
#     'bathrooms': 2.0,
#     'bedrooms': 3.0,
#     'livingArea': 1861.0,
#     'homeType': 'SINGLE_FAMILY',
#     'homeStatus': 'FOR_SALE',
# ...

# %%
#normalizing the data into a dataframe
listings = pd.json_normalize(property_data)
listings = listings['zpid']
listings
# Out:
# 0        1712509
# 1        1761927
# 2        1991746
# 3        1801419
# 4        1710812
#          ...
# 361      1849994
# 362    101673876
# 363      1830804
# 364      1712804
# 365      1773601
# Name: zpid, Length: 366, dtype: object

# %%
#to csv
listings.to_csv('listings.csv')

# %%
# columns of interest
details = ['zpid', 'hdpData.homeInfo.streetAddress','hdpData.homeInfo.city', 'hdpData.homeInfo.state', 'hdpData.homeInfo.zipcode',
           'hdpData.homeInfo.price','hdpData.homeInfo.bedrooms', 'hdpData.homeInfo.bathrooms','hdpData.homeInfo.livingArea','hdpData.homeInfo.homeType', 'hdpData.homeInfo.homeStatus', 'hdpData.homeInfo.daysOnZillow', 'hdpData.homeInfo.zestimate','hdpData.homeInfo.rentZestimate','brokerName', 'hdpData.homeInfo.latitude', 'hdpData.homeInfo.longitude'
 ]

# %%
listings_filter = listings[details]
listings_filter
# Out:
#           zpid hdpData.homeInfo.streetAddress hdpData.homeInfo.city  \
# 0      1838871             2127 Aldrich Ave N           Minneapolis
# 1      1717418             3150 Lyndale Ave S           Minneapolis
# 2      1718034                 1433 35th St W           Minneapolis
# 3      1821671                 1407 6th St NE           Minneapolis
# 4   2054435714         33&35 Melbourne Ave SE           Minneapolis
# ..         ...                            ...                   ...
# 76     1775059             2813 Emerson Ave N           Minneapolis
# 77  2099815390              2625 Columbus Ave           Minneapolis
# 78     1968559             834 Thornton St SE           Minneapolis
# 79     1712804               3641 Clinton Ave           Minneapolis
# 80   132480037               3644 Cedar Ave S           Minneapolis
#
#    hdpData.homeInfo.state hdpData.homeInfo.zipcode  hdpData.homeInfo.price  \
# ...

# %% [markdown]
# ### Listings in Saint Paul (Multifamily)

# %%
url = "https://app.scrapeak.com/v1/scrapers/zillow/listing"
api_key = 'fe4ba972-163e-4dec-8a39-fd9e4e82d6dc'
listing_url = 'https://www.zillow.com/saint-paul-mn/duplex/?searchQueryState=%7B%22isMapVisible%22%3Atrue%2C%22mapBounds%22%3A%7B%22north%22%3A45.009436013156105%2C%22south%22%3A44.869941916105546%2C%22east%22%3A-92.98760714990233%2C%22west%22%3A-93.22449985009764%7D%2C%22usersSearchTerm%22%3A%22Minneapolis%2C%20MN%22%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22manu%22%3A%7B%22value%22%3Afalse%7D%2C%22apa%22%3A%7B%22value%22%3Afalse%7D%2C%22apco%22%3A%7B%22value%22%3Afalse%7D%2C%22land%22%3A%7B%22value%22%3Afalse%7D%2C%22con%22%3A%7B%22value%22%3Afalse%7D%2C%22tow%22%3A%7B%22value%22%3Afalse%7D%2C%22sf%22%3A%7B%22value%22%3Afalse%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A12%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A20313%2C%22regionType%22%3A6%7D%5D%2C%22pagination%22%3A%7B%7D%7D'

querystring = {
        "api_key": api_key,
        "url":listing_url
    }
#transform to json
zp = requests.request("GET", url, params=querystring)
z_forp = zp.json()
z_forp
# Out:
# {'is_success': True,
#  'data': {'user': {'isLoggedIn': False,
#    'hasHousingConnectorPermission': False,
#    'savedHomesCount': 0,
#    'personalizedSearchTraceID': '952b2bad7edc624e17ecc95da0a99356',
#    'guid': '8e77f905-b7f5-4a3b-9d7b-bff638f9ffdd',
#    'zuid': '',
#    'isBot': False,
#    'email': '',
#    'displayName': ''},
#   'mapState': {'customRegionPolygonWkt': None,
#    'schoolPolygonWkt': None,
#    'isCurrentLocationSearch': False,
#    'userPosition': {'lat': None, 'lon': None}},
#   'regionState': {'regionInfo': [{'regionId': 20313,
#      'regionType': 6,
#      'regionName': 'Saint Paul',
#      'displayName': 'Saint Paul MN',
#      'isPointRegion': False}],
#    'regionBounds': {'north': 44.992016,
#     'south': 44.887399,
#     'east': -93.00432,
#     'west': -93.207787}},
#   'searchPageSeoObject': {'baseUrl': '/saint-paul-mn/duplex/',
#    'windowTitle': 'Saint Paul MN Duplex & Triplex Homes For Sale - 46 Homes | Zillow',
# ...

# %%
# view data
property_saint = z_forp["data"]["cat1"]["searchResults"]["mapResults"]
property_saint
# Out:
# [{'zpid': '2144875',
#   'rawHomeStatusCd': 'ForSale',
#   'marketingStatusSimplifiedCd': 'For Sale by Agent',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/0ee96ffaf1310d06cb975a5694a3f605-p_e.jpg',
#   'hasImage': True,
#   'detailUrl': '/homedetails/734-5th-St-E-Saint-Paul-MN-55106/2144875_zpid/',
#   'statusType': 'FOR_SALE',
#   'statusText': 'Multi-family home for sale',
#   'price': '$290,000',
#   'priceLabel': '$290K',
#   'address': '734 5th St E, Saint Paul, MN 55106',
#   'beds': 3,
#   'baths': 2.0,
#   'area': 1844,
#   'latLong': {'latitude': 44.95743, 'longitude': -93.0685},
#   'variableData': {'type': 'PRICE_REDUCTION', 'text': '$10,000 (Jan 6)'},
#   'hdpData': {'homeInfo': {'zpid': 2144875,
#     'streetAddress': '734 5th St E',
#     'zipcode': '55106',
#     'city': 'Saint Paul',
#     'state': 'MN',
#     'latitude': 44.95743,
#     'longitude': -93.0685,
#     'price': 290000.0,
#     'datePriceChanged': 1704528000000,
#     'bathrooms': 2.0,
# ...

# %%
#normalizing the data into a dataframe
listings_saint = pd.json_normalize(property_saint)
#listings_saint.to_csv('saint.csv')
listings_saint
# Out:
#           zpid rawHomeStatusCd marketingStatusSimplifiedCd  \
# 0      2144875         ForSale           For Sale by Agent
# 1      2148500         ForSale           For Sale by Agent
# 2     81752171         ForSale           For Sale by Agent
# 3      2148641         ForSale           For Sale by Agent
# 4      2029390         ForSale           For Sale by Agent
# 5      2145380         ForSale          Non Owner Occupied
# 6      2028176      ComingSoon                 Coming Soon
# 7      2153084         ForSale           For Sale by Agent
# 8      2130933         ForSale           For Sale by Agent
# 9   2067056278         ForSale          Non Owner Occupied
# 10  2057958231         ForSale           For Sale by Agent
# 11     2153544         ForSale           For Sale by Agent
# 12     2120044         ForSale           For Sale by Agent
# 13     2044929         ForSale           For Sale by Agent
# 14     2113827         ForSale           For Sale by Agent
# ...

# %%
listings_filsaint= listings_saint[details]
listings_filsaint
# Out:
#           zpid hdpData.homeInfo.streetAddress hdpData.homeInfo.city  \
# 0      2144875                   734 5th St E            Saint Paul
# 1      2148500                 619 Mendota St            Saint Paul
# 2     81752171                   902 6th St E            Saint Paul
# 3      2148641                   855 4th St E            Saint Paul
# 4      2029390                  32 Douglas St            Saint Paul
# 5      2145380                  291 Bates Ave            Saint Paul
# 6      2028176                 485 Dayton Ave            Saint Paul
# 7      2153084                1518 Pacific St            Saint Paul
# 8      2130933                1311 Reaney Ave            Saint Paul
# 9   2067056278                   667 4th St E            Saint Paul
# 10  2057958231                473 Howell St S            Saint Paul
# 11     2153544           1130 Minnehaha Ave W            Saint Paul
# 12     2120044              1232 Albemarle St            Saint Paul
# ...

# %% [markdown]
# ### Combining(appending) the Minneapolis and Saint Paul Property Datasets

# %%
# Concatenating df1 and df2 with UNION(Or in Python is pd.concat)
union_result = pd.concat([listings_filter, listings_filsaint], ignore_index=True)
union_result
#union_result.to_csv('listings.csv')
# Out:
#            zpid hdpData.homeInfo.streetAddress hdpData.homeInfo.city  \
# 0       1805546             1825 Johnson St NE           Minneapolis
# 1       1803961                2727 Polk St NE           Minneapolis
# 2       1735430                3117 44th Ave S           Minneapolis
# 3       2009631               2101 Grand Ave S           Minneapolis
# 4       1717407             3345 Emerson Ave S           Minneapolis
# ..          ...                            ...                   ...
# 124     2122085              1115 Albemarle St            Saint Paul
# 125     2134556                  902 Forest St            Saint Paul
# 126     2133419           1091 Jessamine Ave E            Saint Paul
# 127     2122443               1029 Virginia St            Saint Paul
# 128  2081238737                1116 Reaney Ave            Saint Paul
#
#     hdpData.homeInfo.state hdpData.homeInfo.zipcode  hdpData.homeInfo.price  \
# ...

# %%
#fil = union_result[union_result['hdpData.homeInfo.streetAddress'] == '1116 Reaney Ave']
#fil

# %% [markdown]
# ## Eagan(Single Family)

# %%
url = "https://app.scrapeak.com/v1/scrapers/zillow/listing"
api_key = 'fe4ba972-163e-4dec-8a39-fd9e4e82d6dc'
listing_url = 'https://www.zillow.com/eagan-mn/houses/?searchQueryState=%7B%22pagination%22%3A%7B%7D%2C%22isMapVisible%22%3Atrue%2C%22mapBounds%22%3A%7B%22west%22%3A-93.28490985009765%2C%22east%22%3A-93.04801714990234%2C%22south%22%3A44.748723956454896%2C%22north%22%3A44.88851188545296%7D%2C%22usersSearchTerm%22%3A%22Eagan%2C%20MN%22%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A17845%2C%22regionType%22%3A6%7D%5D%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22tow%22%3A%7B%22value%22%3Afalse%7D%2C%22mf%22%3A%7B%22value%22%3Afalse%7D%2C%22con%22%3A%7B%22value%22%3Afalse%7D%2C%22land%22%3A%7B%22value%22%3Afalse%7D%2C%22apa%22%3A%7B%22value%22%3Afalse%7D%2C%22manu%22%3A%7B%22value%22%3Afalse%7D%2C%22apco%22%3A%7B%22value%22%3Afalse%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A12%7D'
querystring = {
        "api_key": api_key,
        "url":listing_url
    }
#transform to json
z = requests.request("GET", url, params=querystring)
z_eag = z.json()
z_eag
# Out:
# {'is_success': True,
#  'data': {'user': {'isLoggedIn': False,
#    'hasHousingConnectorPermission': False,
#    'savedHomesCount': 0,
#    'personalizedSearchTraceID': 'f8cecf4c53ca1ce86cfb410cd79f79b5',
#    'guid': '74eaceac-950e-42b2-8a03-55645d46ce39',
#    'zuid': '',
#    'isBot': False,
#    'email': '',
#    'displayName': ''},
#   'mapState': {'customRegionPolygonWkt': None,
#    'schoolPolygonWkt': None,
#    'isCurrentLocationSearch': False,
#    'userPosition': {'lat': None, 'lon': None}},
#   'regionState': {'regionInfo': [{'regionId': 17845,
#      'regionType': 6,
#      'regionName': 'Eagan',
#      'displayName': 'Eagan MN',
#      'isPointRegion': False}],
#    'regionBounds': {'north': 44.861977,
#     'south': 44.775311,
#     'east': -93.104812,
#     'west': -93.228115}},
#   'searchPageSeoObject': {'baseUrl': '/eagan-mn/houses/',
#    'windowTitle': 'Eagan MN Single Family Homes For Sale - 27 Homes | Zillow',
# ...

# %%
property_Eagan = z_eag["data"]["cat1"]["searchResults"]["mapResults"]
property_Eagan
# Out:
# [{'zpid': '1619303',
#   'rawHomeStatusCd': 'ForSale',
#   'marketingStatusSimplifiedCd': 'For Sale by Agent',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/97fff1e4fe2f278d20eb7a719d7e4a0c-p_e.jpg',
#   'hasImage': True,
#   'detailUrl': '/homedetails/2122-Cliffhill-Ln-Eagan-MN-55122/1619303_zpid/',
#   'statusType': 'FOR_SALE',
#   'statusText': 'House for sale',
#   'price': '$369,900',
#   'priceLabel': '$370K',
#   'address': '2122 Cliffhill Ln, Eagan, MN 55122',
#   'beds': 3,
#   'baths': 2.0,
#   'area': 1780,
#   'latLong': {'latitude': 44.793446, 'longitude': -93.215576},
#   'hdpData': {'homeInfo': {'zpid': 1619303,
#     'streetAddress': '2122 Cliffhill Ln',
#     'zipcode': '55122',
#     'city': 'Eagan',
#     'state': 'MN',
#     'latitude': 44.793446,
#     'longitude': -93.215576,
#     'price': 369900.0,
#     'bathrooms': 2.0,
#     'bedrooms': 3.0,
#     'livingArea': 1780.0,
#     'homeType': 'SINGLE_FAMILY',
#     'homeStatus': 'FOR_SALE',
# ...

# %%
listing_Eag = pd.json_normalize(property_Eagan)
listing_Eag
# Out:
#           zpid rawHomeStatusCd marketingStatusSimplifiedCd  \
# 0      1619303         ForSale           For Sale by Agent
# 1      1626573         ForSale           For Sale by Agent
# 2      1619677      ComingSoon                 Coming Soon
# 3      1617182         ForSale           For Sale by Agent
# 4     61189302         ForSale           For Sale by Agent
# 5      1626296         ForSale           For Sale by Agent
# 6      1621019         ForSale           For Sale by Agent
# 7      1624619         ForSale           For Sale by Agent
# 8      1622950      ComingSoon                 Coming Soon
# 9      1624973         ForSale           For Sale by Agent
# 10     1622759         ForSale           For Sale by Agent
# 11     1635313         ForSale           For Sale by Agent
# 12     1630568         ForSale           For Sale by Agent
# 13     1631638         ForSale           For Sale by Agent
# 14     1635887         ForSale           For Sale by Agent
# ...

# %%
listing_Eags = listing_Eag[details]
listing_Eags
# Out:
#           zpid hdpData.homeInfo.streetAddress hdpData.homeInfo.city  \
# 0      1619303              2122 Cliffhill Ln                 Eagan
# 1      1626573            2843 Bridgeview Ter                 Eagan
# 2      1619677                  4261 Amber Ct                 Eagan
# 3      1617182                750 Hackmore Dr                 Eagan
# 4     61189302               4406 Woodgate Cv                 Eagan
# 5      1626296              4109 Blueberry Ln                 Eagan
# 6      1621019               2211 Marilyn Ave                 Eagan
# 7      1624619                4295 Sequoia Dr                 Eagan
# 8      1622950                1435 Cutters Ln                 Eagan
# 9      1624973                 735 Caribou Ln                 Eagan
# 10     1622759          4083 Prairie Ridge Rd                 Eagan
# 11     1635313        935 Lakewood Hills Rd N                 Eagan
# 12     1630568             1740 Crestridge Ln                 Eagan
# ...

# %%
listing_Eags.to_csv('listings.csv')

# %% [markdown]
# ### Woodbury(Single Family)

# %%
url = "https://app.scrapeak.com/v1/scrapers/zillow/listing"
api_key = 'fe4ba972-163e-4dec-8a39-fd9e4e82d6dc'
listing_url = 'https://www.zillow.com/oakdale-mn/houses/?searchQueryState=%7B%22isMapVisible%22%3Atrue%2C%22mapBounds%22%3A%7B%22north%22%3A45.0610267941376%2C%22south%22%3A44.92141514863498%2C%22east%22%3A-92.84160014990236%2C%22west%22%3A-93.07849285009767%7D%2C%22mapZoom%22%3A12%2C%22usersSearchTerm%22%3A%22401%20Main%20St%20NE%20Minneapolis%2C%20MN%2055413%22%2C%22filterState%22%3A%7B%22land%22%3A%7B%22value%22%3Afalse%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22manu%22%3A%7B%22value%22%3Afalse%7D%2C%22apco%22%3A%7B%22value%22%3Afalse%7D%2C%22apa%22%3A%7B%22value%22%3Afalse%7D%2C%22con%22%3A%7B%22value%22%3Afalse%7D%2C%22tow%22%3A%7B%22value%22%3Afalse%7D%2C%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22mf%22%3A%7B%22value%22%3Afalse%7D%7D%2C%22isListVisible%22%3Atrue%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A26248%2C%22regionType%22%3A6%7D%5D%2C%22pagination%22%3A%7B%7D%7D'
querystring = {
        "api_key": api_key,
        "url":listing_url
    }
#transform to json
z = requests.request("GET", url, params=querystring)
z_oak = z.json()
z_oak
# Out:
# {'is_success': True,
#  'data': {'user': {'isLoggedIn': False,
#    'hasHousingConnectorPermission': False,
#    'savedHomesCount': 0,
#    'personalizedSearchTraceID': '89e41d304a7efae5895877caa25df094',
#    'guid': '012f335c-56b9-4165-b13d-95a3dbd620cc',
#    'zuid': '',
#    'isBot': False,
#    'email': '',
#    'displayName': ''},
#   'mapState': {'customRegionPolygonWkt': None,
#    'schoolPolygonWkt': None,
#    'isCurrentLocationSearch': False,
#    'userPosition': {'lat': None, 'lon': None}},
#   'regionState': {'regionInfo': [{'regionId': 26248,
#      'regionType': 6,
#      'regionName': 'Oakdale',
#      'displayName': 'Oakdale MN',
#      'isPointRegion': False}],
#    'regionBounds': {'north': 45.034049,
#     'south': 44.948446,
#     'east': -92.934094,
#     'west': -92.985999}},
#   'searchPageSeoObject': {'baseUrl': '/oakdale-mn/houses/',
#    'windowTitle': 'Oakdale MN Single Family Homes For Sale - 19 Homes | Zillow',
# ...

# %%
property_oak = z_oak["data"]["cat1"]["searchResults"]["mapResults"]
property_oak
# Out:
# [{'zpid': '2271190',
#   'rawHomeStatusCd': 'ForSale',
#   'marketingStatusSimplifiedCd': 'For Sale by Agent',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/33a3d9885cf5f51bed43c55083cbcf58-p_e.jpg',
#   'hasImage': True,
#   'detailUrl': '/homedetails/6848-8th-Street-Ln-N-Oakdale-MN-55128/2271190_zpid/',
#   'statusType': 'FOR_SALE',
#   'statusText': 'House for sale',
#   'price': '$360,000',
#   'priceLabel': '$360K',
#   'address': '6848 8th Street Ln N, Oakdale, MN 55128',
#   'beds': 3,
#   'baths': 2.0,
#   'area': 1712,
#   'latLong': {'latitude': 44.962265, 'longitude': -92.96786},
#   'variableData': {'type': 'OPEN_HOUSE', 'text': 'Open: Sat. 3-5pm'},
#   'hdpData': {'homeInfo': {'zpid': 2271190,
#     'streetAddress': '6848 8th Street Ln N',
#     'zipcode': '55128',
#     'city': 'Oakdale',
#     'state': 'MN',
#     'latitude': 44.962265,
#     'longitude': -92.96786,
#     'price': 360000.0,
#     'bathrooms': 2.0,
#     'bedrooms': 3.0,
#     'livingArea': 1712.0,
# ...

# %%
listing_oak = pd.json_normalize(property_oak)
listing_oak
# Out:
#           zpid rawHomeStatusCd marketingStatusSimplifiedCd  \
# 0      2271190         ForSale           For Sale by Agent
# 1      2269491         ForSale           For Sale by Agent
# 2      2253877         ForSale           For Sale by Agent
# 3      2222392         ForSale           For Sale by Agent
# 4   2066936183         ForSale           For Sale by Agent
# 5          NaN             NaN                         NaN
# 6      2249661         ForSale           For Sale by Agent
# 7      2217421         ForSale           For Sale by Agent
# 8    339934197         ForSale       New Construction Plan
# 9      2252931         ForSale           For Sale by Agent
# 10  2055843755         ForSale       New Construction Plan
# 11   339941035         ForSale       New Construction Plan
# 12   339911718         ForSale       New Construction Plan
# 13   339925136         ForSale       New Construction Plan
# 14   339911454         ForSale       New Construction Plan
# ...

# %%
listing_oak = listing_oak[details]
listing_oak
# Out:
#           zpid hdpData.homeInfo.streetAddress hdpData.homeInfo.city  \
# 0      2271190           6848 8th Street Ln N               Oakdale
# 1      2269491           1175 Greystone Ave N               Oakdale
# 2      2253877               2037 Helmo Ave N               Oakdale
# 3      2222392        4626 Heather Ridge Rd N               Oakdale
# 4   2066936183          6722 13th Street Ct N            Saint Paul
# 5          NaN                            NaN                   NaN
# 6      2249661           2683 Greystone Ave N               Oakdale
# 7      2217421             5023 Grafton Ave N               Oakdale
# 8    339934197              7467 Upper 38th N            Saint Paul
# 9      2252931            2810 Hillvale Trl N               Oakdale
# 10  2055843755           7499 Upper 38th St N            Saint Paul
# 11   339941035              7470 Upper 38th N            Saint Paul
# 12   339911718           7466 Upper 38th St N            Saint Paul
# ...

# %%
listing_oak.to_csv('listings.csv')
